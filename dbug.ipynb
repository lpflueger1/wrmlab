# %%
import numpy as np

import matplotlib.pyplot as plt
print(np.sin(np.pi))

x= np.linespace(1,10,100)
y = np.tan(x)
plt.plot(x,np.cos(x))
plt.show()
# Out:
# 1.2246467991473532e-16
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 6
#       3 import matplotlib.pyplot as plt
#       4 print(np.sin(np.pi))
# ----> 6 x=np.linespace(1,10,100)
#       7 y = np.tan(x)
#       8 plt.plot(x,np.cos(x))
#
# File c:\Users\leoni\miniconda3\envs\test\Lib\site-packages\numpy\__init__.py:792, in __getattr__(attr)
#     789     import numpy.char as char
#     790     return char.chararray
# --> 792 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute 'linespace'
